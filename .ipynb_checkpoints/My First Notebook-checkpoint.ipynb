# %% [markdown]
# My First Jupyter Notebook - created for ZTM_Python

# %%
# Create our first "Class"

class PlayerCharacter:
    def __init__(self, name):
        self.name = name
        
    def run(self):
        print('run')

player1 = PlayerCharacter('Cindy')

print(player1.name)
# Out:
# Cindy
